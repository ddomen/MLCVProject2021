# %%
import os
from getpass import getpass
import urllib
import sys

user = "FiorenzoParascandolo1"
password = getpass('Password: ')
password = urllib.parse.quote(password) # your password is converted into url format
repo_name = "MLCVProject2021"

cmd_string = "git clone https://{0}:{1}@github.com/ddomen/{2}.git".format(user, password, repo_name)

os.system(cmd_string)
cmd_string, password = "", "" # removing the password from the variable
sys.path.append(repo_name)
# Out:
# Password: ········

# %%
from src.dataset import get_dataframe

df = get_dataframe('../input/price-volume-data-for-all-us-stocks-etfs/ETFs')
df.head(5)

# %%
from src.encoding import gasf, gadf
import matplotlib.pyplot as plt

g = gasf(df['Close'], period=1)
plt.matshow(g, cmap='Spectral')
plt.savefig('/kaggle/working/test.png')

g = gadf(df['Close'], period=1)
plt.matshow(g, cmap='Spectral')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(df['Trend'][:100])
plt.title('Closing price')
plt.show()
